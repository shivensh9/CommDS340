# %%
# !unzip CommDS340.zip
# Out:
# Archive:  CommDS340.zip
#    creating: CommDS340/
#   inflating: __MACOSX/._CommDS340
#   inflating: CommDS340/.DS_Store
#   inflating: __MACOSX/CommDS340/._.DS_Store
#  extracting: CommDS340/requirements.txt
#   inflating: __MACOSX/CommDS340/._requirements.txt
#    creating: CommDS340/raw_data/
#   inflating: __MACOSX/CommDS340/._raw_data
#  extracting: CommDS340/README.md
#   inflating: __MACOSX/CommDS340/._README.md
#    creating: CommDS340/.git/
#   inflating: __MACOSX/CommDS340/._.git
#  extracting: CommDS340/main.py
#   inflating: __MACOSX/CommDS340/._main.py
#   inflating: CommDS340/raw_data/.DS_Store
#   inflating: __MACOSX/CommDS340/raw_data/._.DS_Store
#    creating: CommDS340/raw_data/data/
#   inflating: __MACOSX/CommDS340/raw_data/._data
#    creating: CommDS340/raw_data/src/
#   inflating: __MACOSX/CommDS340/raw_data/._src
#   inflating: CommDS340/.git/.DS_Store
#   inflating: __MACOSX/CommDS340/.git/._.DS_Store
#   inflating: CommDS340/.git/ORIG_HEAD
# ...

# %%
# !unzip t5_basketball_model.zip
# Out:
# Archive:  t5_basketball_model.zip
#    creating: t5_basketball_model/
#   inflating: __MACOSX/._t5_basketball_model
#   inflating: t5_basketball_model/model.safetensors
#   inflating: __MACOSX/t5_basketball_model/._model.safetensors
#    creating: t5_basketball_model/checkpoint-36060/
#   inflating: __MACOSX/t5_basketball_model/._checkpoint-36060
#   inflating: t5_basketball_model/added_tokens.json
#   inflating: __MACOSX/t5_basketball_model/._added_tokens.json
#   inflating: t5_basketball_model/tokenizer_config.json
#   inflating: __MACOSX/t5_basketball_model/._tokenizer_config.json
#   inflating: t5_basketball_model/special_tokens_map.json
#   inflating: __MACOSX/t5_basketball_model/._special_tokens_map.json
#   inflating: t5_basketball_model/config.json
#   inflating: __MACOSX/t5_basketball_model/._config.json
#   inflating: t5_basketball_model/generation_config.json
#   inflating: __MACOSX/t5_basketball_model/._generation_config.json
# ...

# %%
# !python /content/CommDS340/raw_data/src/model/run_experiments.py
# Out:
# 2025-04-28 15:29:40.465460: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745854180.485094   17788 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745854180.491148   17788 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-28 15:29:40.512235: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0.2 0.3
# ...
