# %%
# !unzip CommDS340.zip
# Out:
# Archive:  CommDS340.zip
#    creating: CommDS340/
#   inflating: __MACOSX/._CommDS340
#   inflating: CommDS340/.DS_Store
#   inflating: __MACOSX/CommDS340/._.DS_Store
#  extracting: CommDS340/requirements.txt
#   inflating: __MACOSX/CommDS340/._requirements.txt
#    creating: CommDS340/raw_data/
#   inflating: __MACOSX/CommDS340/._raw_data
#  extracting: CommDS340/README.md
#   inflating: __MACOSX/CommDS340/._README.md
#    creating: CommDS340/.git/
#   inflating: __MACOSX/CommDS340/._.git
#  extracting: CommDS340/main.py
#   inflating: __MACOSX/CommDS340/._main.py
#   inflating: CommDS340/raw_data/.DS_Store
#   inflating: __MACOSX/CommDS340/raw_data/._.DS_Store
#    creating: CommDS340/raw_data/data/
#   inflating: __MACOSX/CommDS340/raw_data/._data
#    creating: CommDS340/raw_data/src/
#   inflating: __MACOSX/CommDS340/raw_data/._src
#   inflating: CommDS340/.git/.DS_Store
#   inflating: __MACOSX/CommDS340/.git/._.DS_Store
#   inflating: CommDS340/.git/ORIG_HEAD
# ...

# %%
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install transformers

# %%
# !python /content/CommDS340/raw_data/src/model/train_custom_lstm.py
# Out:
# Epoch 1/5, Loss: 2.8933
# Epoch 2/5, Loss: 1.4005
# Epoch 3/5, Loss: 1.0932
# Epoch 4/5, Loss: 0.9431
# Epoch 5/5, Loss: 0.8498
# ✅ Model saved.
# Test Accuracy (Token-Level): 77.53%
